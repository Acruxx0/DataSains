# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#load data
df = pd.read_csv("calon_tni.csv")

# cetak informasi dari data frame
print("========================== Data Calon TNI ==========================")
print("=" * 68)
print(df)
print("=" * 68)

print()
print()

# cetak statistik deskriptif
print("=" * 68)
print("======================= Statistik Deskriptif =======================")
print(df.describe())

print()
print()

# deteksi masalah dalam data / missing value
print("=" * 42)
print("====== Deteksi Masalah Missing Value =====")
print(df.isnull().sum())

print()
print()

# data anomali atau data yang tidak wajar
print("=" * 47)
print("====== Deteksi Data Tidak Wajar / Anomali =====")
gaji_maks = df["gaji"].max()
gaji_mini = df["gaji"].min()
rata_rata = df["gaji"].mean()
nama_kosong = df["nama"].isnull().sum()
alamat_kosong = df["alamat"].isnull().sum()
tinggi_kosong = df["tinggi"].isnull().sum()
jenis_kelamin_kosong = df["jenis_kelamin"].isnull().sum()
gaji_kosong = df["gaji"].isnull().sum()
print(f"Gaji Paling Tinggi: {gaji_maks:,}".replace(",", "."))
print(f"Gaji Paling Rendah: {gaji_mini:,}".replace(",", "."))
print(f"Rata-Rata Gaji: {rata_rata:,}".replace(",", "."))
print(f"Nama kosong: {nama_kosong} data")
print(f"Alamat kosong: {alamat_kosong} data")
print(f"Tinggi badan kosong: {tinggi_kosong} data")
print(f"Jenis kelamin kosong: {jenis_kelamin_kosong} data")
print(f"Gaji kosong: {gaji_kosong} data")
# Out:
# ========================== Data Calon TNI ==========================
# ====================================================================
#     nama                    alamat  tinggi
# 0   Andi        Jl. Merdeka No. 10     175
# 1   Budi        Jl. Sudirman No. 5     178
# 2  Citra        Jl. Thamrin No. 20     180
# 3   Dewi  Jl. Gatot Subroto No. 15     180
# 4    Eka     Jl. Rasuna Said No. 8     183
# 5  Fajar       Jl. Kuningan No. 12     185
# 6   Gina          Jl. Cikini No. 3     170
# 7   Hadi        Jl. Palmerah No. 7     168
# 8  Indah         Jl. Senayan No. 9     178
# 9  Jilan        Jl. Kuningan No. 2     160
# ====================================================================
#
#
# ====================================================================
# ======================= Statistik Deskriptif =======================
#            tinggi
# count   10.000000
# mean   175.700000
# std      7.645623
# min    160.000000
# 25%    171.250000
# 50%    178.000000
# 75%    180.000000
# max    185.000000
#
#
# ==========================================
# ====== Deteksi Masalah Missing Value =====
# nama      0
# alamat    0
# tinggi    0
# dtype: int64
#
#
# ===============================================
# ====== Deteksi Data Tidak Wajar / Anomali =====
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Python\DataSains\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gaji'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 36
#      34 print("=" * 47)
#      35 print("====== Deteksi Data Tidak Wajar / Anomali =====")
# ---> 36 gaji_maks = df["gaji"].max()
#      37 gaji_mini = df["gaji"].min()
#      38 rata_rata = df["gaji"].mean()
#
# File D:\Python\DataSains\venv\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File D:\Python\DataSains\venv\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'gaji'
